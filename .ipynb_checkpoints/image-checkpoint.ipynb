# %%
from numpy import random as r
from matplotlib import pyplot as p

# %%
im = r.rand(256,256)
p.imshow(im, cmap='gray')

# %%
im[0:64,0:32]=0
p.imshow(im, cmap='gray')

# %%
im = r.rand(256,256,3)
p.imshow(im)

# %%
im.shape
# Out:
# (256, 256, 3)
